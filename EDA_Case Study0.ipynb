# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
from datetime import timedelta

# %%
df = pd.read_csv('inda_covid.csv')

# %%
df
# Out:
#      iso_code continent location        date    year     month  total_cases  \
# 0         IND      Asia    India  30-01-2020  2020.0   January          1.0
# 1         IND      Asia    India  31-01-2020  2020.0   January          1.0
# 2         IND      Asia    India  01-02-2020  2020.0  February          1.0
# 3         IND      Asia    India  02-02-2020  2020.0  February          2.0
# 4         IND      Asia    India  03-02-2020  2020.0  February          3.0
# ...       ...       ...      ...         ...     ...       ...          ...
# 1344      NaN       NaN      NaN         NaN     NaN       NaN          NaN
# 1345      NaN       NaN      NaN         NaN     NaN       NaN          NaN
# 1346      NaN       NaN      NaN         NaN     NaN       NaN          NaN
# 1347      NaN       NaN      NaN         NaN     NaN       NaN          NaN
# 1348      NaN       NaN      NaN         NaN     NaN       NaN          NaN
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      iso_code continent location        date    year     month  total_cases  \
# 0         IND      Asia    India  30-01-2020  2020.0   January          1.0
# 1         IND      Asia    India  31-01-2020  2020.0   January          1.0
# 2         IND      Asia    India  01-02-2020  2020.0  February          1.0
# 3         IND      Asia    India  02-02-2020  2020.0  February          2.0
# 4         IND      Asia    India  03-02-2020  2020.0  February          3.0
# ...       ...       ...      ...         ...     ...       ...          ...
# 1344      NaN       NaN      NaN         NaN     NaN       NaN          NaN
# 1345      NaN       NaN      NaN         NaN     NaN       NaN          NaN
# 1346      NaN       NaN      NaN         NaN     NaN       NaN          NaN
# 1347      NaN       NaN      NaN         NaN     NaN       NaN          NaN
# 1348      NaN       NaN      NaN         NaN     NaN       NaN          NaN
#
# ...

# %%
df.head()
# Out:
#   iso_code continent location        date    year     month  total_cases  \
# 0      IND      Asia    India  30-01-2020  2020.0   January          1.0
# 1      IND      Asia    India  31-01-2020  2020.0   January          1.0
# 2      IND      Asia    India  01-02-2020  2020.0  February          1.0
# 3      IND      Asia    India  02-02-2020  2020.0  February          2.0
# 4      IND      Asia    India  03-02-2020  2020.0  February          3.0
#
#    new_cases  new_cases_smoothed  total_deaths  ...  female_smokers  \
# 0        1.0                 NaN           NaN  ...             1.9
# 1        0.0                 NaN           NaN  ...             1.9
# 2        0.0                 NaN           NaN  ...             1.9
# 3        1.0                 NaN           NaN  ...             1.9
# 4        1.0                 NaN           NaN  ...             1.9
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'year', 'month',
#        'total_cases', 'new_cases', 'new_cases_smoothed', 'total_deaths',
#        'new_deaths', 'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'total_tests',
#        'new_tests', 'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million',
# ...

# %%
df.isna()
# Out:
#       iso_code  continent  location   date   year  month  total_cases  \
# 0        False      False     False  False  False  False        False
# 1        False      False     False  False  False  False        False
# 2        False      False     False  False  False  False        False
# 3        False      False     False  False  False  False        False
# 4        False      False     False  False  False  False        False
# ...        ...        ...       ...    ...    ...    ...          ...
# 1344      True       True      True   True   True   True         True
# 1345      True       True      True   True   True   True         True
# 1346      True       True      True   True   True   True         True
# 1347      True       True      True   True   True   True         True
# 1348      True       True      True   True   True   True         True
#
#       new_cases  new_cases_smoothed  total_deaths  ...  female_smokers  \
# ...

# %%
df.isna().sum()
# Out:
# iso_code                                    505
# continent                                   505
# location                                    505
# date                                        505
# year                                        505
#                                            ...
# human_development_index                     505
# excess_mortality_cumulative_absolute       1349
# excess_mortality_cumulative                1349
# excess_mortality                           1349
# excess_mortality_cumulative_per_million    1349
# Length: 61, dtype: int64

# %%
sns.heatmap(df.isnull(), yticklabels=False, cmap='plasma')
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'year', 'month',
#        'total_cases', 'new_cases', 'new_cases_smoothed', 'total_deaths',
#        'new_deaths', 'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'total_tests',
#        'new_tests', 'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million',
# ...

# %%
df.drop(['new_deaths_smoothed', 'total_cases_per_million', 'new_cases_per_million', 'total_deaths_per_million', 
         'new_deaths_per_million', 'reproduction_rate', 'new_cases_smoothed', 'total_tests_per_thousand', 'new_tests_per_thousand', 'extreme_poverty','cardiovasc_death_rate', 
       'diabetes_prevalence', 'female_smokers', 'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
       'life_expectancy', 'human_development_index', 'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
       'excess_mortality', 'excess_mortality_cumulative_per_million','new_tests_smoothed', 'new_tests_smoothed_per_thousand',
       'stringency_index'], axis=1, inplace=True)

# %%
df.shape
# Out:
# (1349, 36)

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'year', 'month',
#        'total_cases', 'new_cases', 'total_deaths', 'new_deaths',
#        'new_cases_smoothed_per_million', 'new_deaths_smoothed_per_million',
#        'total_tests', 'new_tests', 'positive_rate', 'tests_per_case',
#        'tests_units', 'total_vaccinations', 'people_vaccinated',
#        'people_fully_vaccinated', 'total_boosters', 'new_vaccinations',
#        'new_vaccinations_smoothed', 'total_vaccinations_per_hundred',
#        'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred',
#        'total_boosters_per_hundred', 'new_vaccinations_smoothed_per_million',
#        'new_people_vaccinated_smoothed',
#        'new_people_vaccinated_smoothed_per_hundred', 'population',
#        'population_density', 'median_age', 'aged_65_older', 'aged_70_older',
#        'gdp_per_capita'],
#       dtype='object')

# %%
sns.heatmap(df.isnull(), yticklabels=False, cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
df.tail().isna().sum()
# Out:
# iso_code                                      5
# continent                                     5
# location                                      5
# date                                          5
# year                                          5
# month                                         5
# total_cases                                   5
# new_cases                                     5
# total_deaths                                  5
# new_deaths                                    5
# new_cases_smoothed_per_million                5
# new_deaths_smoothed_per_million               5
# total_tests                                   5
# new_tests                                     5
# positive_rate                                 5
# tests_per_case                                5
# tests_units                                   5
# total_vaccinations                            5
# people_vaccinated                             5
# people_fully_vaccinated                       5
# ...

# %%
df.drop(['iso_code', 'continent', 'total_cases', 'new_cases', 'total_deaths', 'new_deaths', 'total_tests',
         'new_tests', 'tests_per_case', 'tests_units','population', 'population_density', 'median_age', 'aged_65_older',
         'aged_70_older', 'gdp_per_capita'], axis=1, inplace=True)

# %%
df
# Out:
#      location        date    year     month  new_cases_smoothed_per_million  \
# 0       India  30-01-2020  2020.0   January                             NaN
# 1       India  31-01-2020  2020.0   January                             NaN
# 2       India  01-02-2020  2020.0  February                             NaN
# 3       India  02-02-2020  2020.0  February                             NaN
# 4       India  03-02-2020  2020.0  February                             NaN
# ...       ...         ...     ...       ...                             ...
# 1344      NaN         NaN     NaN       NaN                             NaN
# 1345      NaN         NaN     NaN       NaN                             NaN
# 1346      NaN         NaN     NaN       NaN                             NaN
# 1347      NaN         NaN     NaN       NaN                             NaN
# 1348      NaN         NaN     NaN       NaN                             NaN
#
# ...

# %%
df.columns
# Out:
# Index(['location', 'date', 'year', 'month', 'new_cases_smoothed_per_million',
#        'new_deaths_smoothed_per_million', 'positive_rate',
#        'total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated',
#        'total_boosters', 'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million',
#        'new_people_vaccinated_smoothed',
#        'new_people_vaccinated_smoothed_per_hundred'],
#       dtype='object')

# %%
'''
df.dropna(subset=['total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated',
       'total_boosters', 'new_vaccinations', 'new_vaccinations_smoothed',
       'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
       'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
       'new_vaccinations_smoothed_per_million',
       'new_people_vaccinated_smoothed',
       'new_people_vaccinated_smoothed_per_hundred'], inplace=True)
'''
df.dropna(subset=['location'], inplace=True)

# %%
df
# Out:
#     location        date    year     month  new_cases_smoothed_per_million  \
# 0      India  30-01-2020  2020.0   January                             NaN
# 1      India  31-01-2020  2020.0   January                             NaN
# 2      India  01-02-2020  2020.0  February                             NaN
# 3      India  02-02-2020  2020.0  February                             NaN
# 4      India  03-02-2020  2020.0  February                             NaN
# ..       ...         ...     ...       ...                             ...
# 839    India  18-05-2022  2022.0       May                           1.656
# 840    India  19-05-2022  2022.0       May                           1.596
# 841    India  20-05-2022  2022.0       May                           1.541
# 842    India  21-05-2022  2022.0       May                           1.514
# 843    India  22-05-2022  2022.0       May                           1.496
#
# ...

# %%
df['location'].value_counts()
# Out:
# India    844
# Name: location, dtype: int64

# %%
df
# Out:
#     location        date    year     month  new_cases_smoothed_per_million  \
# 0      India  30-01-2020  2020.0   January                             NaN
# 1      India  31-01-2020  2020.0   January                             NaN
# 2      India  01-02-2020  2020.0  February                             NaN
# 3      India  02-02-2020  2020.0  February                             NaN
# 4      India  03-02-2020  2020.0  February                             NaN
# ..       ...         ...     ...       ...                             ...
# 839    India  18-05-2022  2022.0       May                           1.656
# 840    India  19-05-2022  2022.0       May                           1.596
# 841    India  20-05-2022  2022.0       May                           1.541
# 842    India  21-05-2022  2022.0       May                           1.514
# 843    India  22-05-2022  2022.0       May                           1.496
#
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df['new_vaccinations'].isnull().sum()
# Out:
# 381

# %%
df.dropna(subset=['new_vaccinations'], inplace=True)

# %%
#df["date"]=pd.to_datetime(df["date"])

# %%
plt.figure(figsize=(20,10))
plt.scatter(df.date, df.new_vaccinations)

# %%
plt.figure(figsize=(20,10))
plt.plot(df.date, df.new_vaccinations, '-.')

# %%
plt.figure(figsize=(20,10))
df['new_vaccinations'].plot()
# Out:
# <AxesSubplot:>

# %%
df['date'].head()
# Out:
# 352    16-01-2021
# 353    17-01-2021
# 354    18-01-2021
# 355    19-01-2021
# 356    20-01-2021
# Name: date, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df.drop('index', axis=1, inplace=True)

# %%
df
# Out:
#     location        date    year    month  new_cases_smoothed_per_million  \
# 0      India  16-01-2021  2021.0  January                          11.042
# 1      India  17-01-2021  2021.0  January                          10.783
# 2      India  18-01-2021  2021.0  January                          10.523
# 3      India  19-01-2021  2021.0  January                          10.303
# 4      India  20-01-2021  2021.0  January                          10.128
# ..       ...         ...     ...      ...                             ...
# 458    India  18-05-2022  2022.0      May                           1.656
# 459    India  19-05-2022  2022.0      May                           1.596
# 460    India  20-05-2022  2022.0      May                           1.541
# 461    India  21-05-2022  2022.0      May                           1.514
# 462    India  22-05-2022  2022.0      May                           1.496
#
#      new_deaths_smoothed_per_million  positive_rate  total_vaccinations  \
# ...

# %%
df1 = df['date']<'31-12-2021'

# %%
#plt.figure(figsize=(6,3))
df['new_cases_smoothed_per_million'].plot()
# Out:
# <AxesSubplot:>

# %%
plt.plot(df['date'], df['new_cases_smoothed_per_million'])

# %%
plt.plot(df['date'], df['new_deaths_smoothed_per_million'])

# %%
plt.plot(df['date'], df['positive_rate'])

# %%
plt.gca().set(xlim=(0.0, 0.1), ylim=(0, 90000),
              xlabel='Area', ylabel='Population')

plt.xticks(fontsize=12); plt.yticks(fontsize=12)
plt.title("Bubble Plot with Encircling", fontsize=22)
plt.legend(fontsize=12)    
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df.columns
# Out:
# Index(['location', 'date', 'year', 'month', 'new_cases_smoothed_per_million',
#        'new_deaths_smoothed_per_million', 'positive_rate',
#        'total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated',
#        'total_boosters', 'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million',
#        'new_people_vaccinated_smoothed',
#        'new_people_vaccinated_smoothed_per_hundred'],
#       dtype='object')

# %%
df.dropna(subset=['location', 'date', 'year', 'month', 'new_cases_smoothed_per_million',
       'new_deaths_smoothed_per_million', 'positive_rate',
       'total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated',
       'total_boosters', 'new_vaccinations', 'new_vaccinations_smoothed',
       'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
       'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
       'new_vaccinations_smoothed_per_million',
       'new_people_vaccinated_smoothed',
       'new_people_vaccinated_smoothed_per_hundred'], inplace=True)

# %%
df
# Out:
#     location        date    year    month  new_cases_smoothed_per_million  \
# 341    India  13-01-2022  2022.0  January                         138.995
# 342    India  14-01-2022  2022.0  January                         152.000
# 343    India  15-01-2022  2022.0  January                         163.439
# 344    India  16-01-2022  2022.0  January                         171.473
# 346    India  18-01-2022  2022.0  January                         187.693
# ..       ...         ...     ...      ...                             ...
# 454    India  14-05-2022  2022.0      May                           1.989
# 455    India  15-05-2022  2022.0      May                           1.886
# 456    India  16-05-2022  2022.0      May                           1.813
# 457    India  17-05-2022  2022.0      May                           1.703
# 458    India  18-05-2022  2022.0      May                           1.656
#
#      new_deaths_smoothed_per_million  positive_rate  total_vaccinations  \
# ...

# %%
df
# Out:
#     location        date    year    month  new_cases_smoothed_per_million  \
# 341    India  13-01-2022  2022.0  January                         138.995
# 342    India  14-01-2022  2022.0  January                         152.000
# 343    India  15-01-2022  2022.0  January                         163.439
# 344    India  16-01-2022  2022.0  January                         171.473
# 346    India  18-01-2022  2022.0  January                         187.693
# ..       ...         ...     ...      ...                             ...
# 454    India  14-05-2022  2022.0      May                           1.989
# 455    India  15-05-2022  2022.0      May                           1.886
# 456    India  16-05-2022  2022.0      May                           1.813
# 457    India  17-05-2022  2022.0      May                           1.703
# 458    India  18-05-2022  2022.0      May                           1.656
#
#      new_deaths_smoothed_per_million  positive_rate  total_vaccinations  \
# ...

# %%
plt.scatter(df.date, df.new_vaccinations)
